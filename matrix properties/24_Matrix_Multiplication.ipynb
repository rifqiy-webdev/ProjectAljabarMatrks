# %% [markdown]
# SOAL 1

# %%
# buat matrix A dengan ukuran 2x3 dan vector b berukuran 3x1 menggunakan numpy
import numpy as np

A = np.array([[1, 2, 3], [4, 5, 6]])

print (A)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
b = np.array([[2], [5], [5]])

print (b)
# Out:
# [[2]
#  [5]
#  [5]]

# %%
# buat matrix A_pt dengan ukuran 2x3 dan vector b_pt berukuran 3x1 menggunakan pytorch
import torch

A_pt = torch.tensor([[1, 2, 3], [4, 5, 6]])

print (A_pt)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
b_pt = torch.tensor([[2], [5], [5]])

print (b_pt)
# Out:
# tensor([[2],
#         [5],
#         [5]])

# %%
# buat matrix A_tf dengan ukuran 2x3 dan vector b_tf berukuran 3x1 menggunakan tensorflow
import tensorflow as tf

A_tf = tf.Variable([[1, 2, 3], [4, 5, 6]])

print (A_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)>

# %%
b_tf = tf.Variable([[2], [5], [5]])

print (b_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=int32, numpy=
# array([[2],
#        [5],
#        [5]], dtype=int32)>

# %% [markdown]
# SOAL 2

# %%
# tampilkan ukuran matrix A dan vector b
print ("Ukuran matrix A:", A.shape)
print ("Ukuran vector b:", b.shape)
# Out:
# Ukuran matrix A: (2, 3)
# Ukuran vector b: (3, 1)

# %% [markdown]
# SOAL 3

# %%
# kalikan matrix A dengan vector b
np.dot(A, b)
# Out:
# array([[27],
#        [63]])

# %%
# kalikan matrix A_pt dengan vector b_pt
torch.matmul(A_pt, b_pt)
# Out:
# tensor([[27],
#         [63]])

# %%
# kalikan matrix A_tf dengan vector b_tf
tf.matmul(A_tf, b_tf)
# Out:
# <tf.Tensor: shape=(2, 1), dtype=int32, numpy=
# array([[27],
#        [63]], dtype=int32)>

# %% [markdown]
# SOAL 4

# %%
# buat matrix B dengan ukuran 3x3 menggunakan numpy
B = np.array([[2, 5, 5], [0, 6, 1], [0, 0, 6]])

print (B)
# Out:
# [[2 5 5]
#  [0 6 1]
#  [0 0 6]]

# %%
# buat matrix B_pt dengan ukuran 3x3 menggunakan pytorch
B_pt = torch.tensor([[2, 5, 5], [0, 6, 1], [0, 0, 6]])

print (B_pt)
# Out:
# tensor([[2, 5, 5],
#         [0, 6, 1],
#         [0, 0, 6]])

# %%
# buat matrix B_tf dengan ukuran 3x3 menggunakan tensorflow
B_tf = tf.Variable([[2, 5, 5], [0, 6, 1], [0, 0, 6]])

print (B_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 3) dtype=int32, numpy=
# array([[2, 5, 5],
#        [0, 6, 1],
#        [0, 0, 6]], dtype=int32)>

# %% [markdown]
# SOAL 5

# %%
# kalikan matrix A dengan matrix B
np.dot(A, B)
# Out:
# array([[ 2, 17, 25],
#        [ 8, 50, 61]])

# %%
# kalikan matrix A_pt dengan matrix B_pt
torch.matmul(A_pt, B_pt)
# Out:
# tensor([[ 2, 17, 25],
#         [ 8, 50, 61]])

# %%
# kalikan matrix A_tf dengan matrix B_tf
tf.matmul(A_tf, B_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 2, 17, 25],
#        [ 8, 50, 61]], dtype=int32)>

# %% [markdown]
# SOAL 6

# %%
# buktikan apakah perkalian matrix bersifat komutatif? (AB=BA)?
np.dot(A, B)

#np.dot (B, A) tidak bisa dijalankan dikarenakan Error
# Out:
# array([[ 2, 17, 25],
#        [ 8, 50, 61]])

# %%
np.dot (B, A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10830/2289930374.py in <cell line: 0>()
# ----> 1 np.dot (B, A)
#
# ValueError: shapes (3,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)
